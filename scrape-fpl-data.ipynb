# %%
# get list of player_ids
player_ids = requests.get('https://fantasy.premierleague.com/drf/elements/').json()

# %%
# example with Ospina (id: 0):
player_ids[0]['web_name'].encode('ascii')
# Out:
# b'Ospina'

# %%
dict_players
# Out:
# {0: 'Ospina',
#  1: 'Cech',
#  2: 'Martinez',
#  3: 'Koscielny',
#  4: 'Mertesacker',
#  5: 'Gabriel',
#  6: 'Bellerín',
#  7: 'Jenkinson',
#  8: 'Monreal',
#  9: 'Holding',
#  10: 'Mustafi',
#  11: 'Kolasinac',
#  12: 'Özil',
#  13: 'Cazorla',
#  14: 'Ramsey',
#  15: 'Coquelin',
#  16: 'Iwobi',
#  17: 'Elneny',
#  18: 'Xhaka',
#  19: 'Wilshere',
#  20: 'Welbeck',
#  21: 'Pérez',
#  22: 'Lacazette',
#  23: 'Mkhitaryan',
#  24: 'Chambers',
#  25: 'Nelson',
#  26: 'Maitland-Niles',
#  27: 'Macey',
#  28: 'Nketiah',
#  29: 'Debuchy',
#  30: 'Mavropanos',
#  31: 'Aubameyang',
#  32: 'Begovic',
#  33: 'Boruc',
#  34: 'Federici',
#  35: 'Francis',
#  36: 'Steve Cook',
#  37: 'Daniels',
#  38: 'Adam Smith',
#  39: 'Mings',
#  40: 'Brad Smith',
#  41: 'Aké',
#  42: 'Arter',
#  43: 'Pugh',
#  44: 'Surman',
#  45: 'Stanislas',
#  46: 'Gosling',
#  47: 'Gradel',
#  48: 'Ibe',
#  49: 'Lewis Cook',
#  50: 'Fraser',
#  51: 'Wilson',
#  52: 'Afobe',
#  53: 'Mousset',
#  54: 'King',
#  55: 'Defoe',
#  56: 'Ramsdale',
#  57: 'Simpson',
#  58: 'Hyndman',
#  59: 'Mahoney',
#  60: 'Butcher',
#  61: 'Taylor',
#  62: 'Mäenpää',
#  63: 'Ryan',
#  64: 'Dunk',
#  65: 'Duffy',
#  66: 'Hünemeier',
#  67: 'Bruno',
#  68: 'Bong',
#  69: 'Rosenior',
#  70: 'Goldson',
#  71: 'Knockaert',
#  72: 'Stephens',
#  73: 'Kayal',
#  74: 'Sidwell',
#  75: 'March',
#  76: 'Skalak',
#  77: 'Norwood',
#  78: 'Murphy',
#  79: 'Groß',
#  80: 'Murray',
#  81: 'Hemed',
#  82: 'Baldock',
#  83: 'Ulloa',
#  84: 'Suttner',
#  85: 'Brown',
#  86: 'Pröpper',
#  87: 'Izquierdo',
#  88: 'Schelotto',
#  89: 'Krul',
#  90: 'Molumby',
#  91: 'Locadia',
#  92: 'Heaton',
#  93: 'Robinson',
#  94: 'Lowton',
#  95: 'Mee',
#  96: 'Ward',
#  97: 'Tarkowski',
#  98: 'Long',
#  99: 'Taylor',
#  100: 'Arfield',
#  101: 'Marney',
#  102: 'Gudmundsson',
#  103: 'Defour',
#  104: 'Hendrick',
#  105: 'Brady',
#  106: 'Westwood',
#  107: 'Walters',
#  108: 'Cork',
#  109: 'Vokes',
#  110: 'Barnes',
#  111: 'Lennon',
#  112: 'Wells',
#  113: 'Bardsley',
#  114: 'Nkoudou',
#  115: 'Pope',
#  116: 'Wood',
#  117: 'Legzdins',
#  118: 'Lindegaard',
#  119: 'Ulvestad',
#  120: "O'Neill",
#  121: 'Giroud',
#  122: 'Courtois',
#  123: 'Eduardo',
#  124: 'Caballero',
#  125: 'Azpilicueta',
#  126: 'Cahill',
#  127: 'Alonso',
#  128: 'David Luiz',
#  129: 'Moses',
#  130: 'Rüdiger',
#  131: 'Hazard',
#  132: 'Fàbregas',
#  133: 'Willian',
#  134: 'Pedro',
#  135: 'Kanté',
#  136: 'Batshuayi',
#  137: 'Costa',
#  138: 'Barkley',
#  139: 'Palmer',
#  140: 'Drinkwater',
#  141: 'Bakayoko',
#  142: 'Christensen',
#  143: 'Musonda',
#  144: 'Morata',
#  145: 'Tomori',
#  146: 'Scott',
#  147: 'Boga',
#  148: 'Zappacosta',
#  149: 'Ampadu',
#  150: 'Hudson-Odoi',
#  151: 'Sterling',
#  152: 'Emerson',
#  153: 'Loftus-Cheek',
#  154: 'Hennessey',
#  155: 'Speroni',
#  156: 'Tomkins',
#  157: 'Dann',
#  158: 'Ward',
#  159: 'Kelly',
#  160: 'Delaney',
#  161: 'Souaré',
#  162: 'Schlupp',
#  163: 'van Aanholt',
#  164: 'Puncheon',
#  165: 'Zaha',
#  166: 'McArthur',
#  167: 'Lee Chung-yong',
#  168: 'Cabaye',
#  169: 'Sako',
#  170: 'Townsend',
#  171: 'Milivojevic',
#  172: 'Wickham',
#  173: 'Benteke',
#  174: 'Sakho',
#  175: 'Fosu-Mensah',
#  176: 'Riedewald',
#  177: 'Lokilo',
#  178: 'Ladapo',
#  179: 'Kaikai',
#  180: 'Anderson',
#  181: 'Lumeka',
#  182: 'Mutch',
#  183: 'Henry',
#  184: 'Wan-Bissaka',
#  185: 'Jach',
#  186: 'Rakip',
#  187: 'Sørloth',
#  188: 'Kirby',
#  189: 'Walcott',
#  190: 'Pickford',
#  191: 'Robles',
#  192: 'Stekelenburg',
#  193: 'Baines',
#  194: 'Coleman',
#  195: 'Jagielka',
#  196: 'Pennington',
#  197: 'Funes Mori',
#  198: 'Williams',
#  199: 'Holgate',
#  200: 'Kenny',
#  201: 'Keane',
#  202: 'Bolasie',
#  203: 'Mirallas',
#  204: 'McCarthy',
#  205: 'Besic',
#  206: 'Schneiderlin',
#  207: 'Gueye',
#  208: 'Davies',
#  209: 'Lookman',
#  210: 'Klaassen',
#  211: 'Calvert-Lewin',
#  212: 'Sandro',
#  213: 'Rooney',
#  214: 'Sigurdsson',
#  215: 'Martina',
#  216: 'Mangala',
#  217: 'Vlasic',
#  218: 'Niasse',
#  219: 'Baningime',
#  220: 'Tosun',
#  221: 'Garbutt',
#  222: 'Coleman',
#  223: 'Lössl',
#  224: 'Schindler',
#  225: 'Löwe',
#  226: 'Smith',
#  227: 'Hefele',
#  228: 'Cranie',
#  229: 'Stankovic',
#  230: 'Hudson',
#  231: 'Zanka',
#  232: 'Mooy',
#  233: 'van La Parra',
#  234: 'Hogg',
#  235: 'Billing',
#  236: 'Lolley',
#  237: 'Payne',
#  238: 'Whitehead',
#  239: 'Bunn',
#  240: 'Scannell',
#  241: 'Kachunga',
#  242: 'Ince',
#  243: 'Williams',
#  244: 'Quaner',
#  245: 'Depoitre',
#  246: 'Mounie',
#  247: 'Malone',
#  248: 'Hadergjonaj',
#  249: 'Sabiri',
#  250: 'Green',
#  251: 'Kongolo',
#  252: 'Pritchard',
#  253: 'Schmeichel',
#  254: 'Hamer',
#  255: 'Morgan',
#  256: 'Fuchs',
#  257: 'Simpson',
#  258: 'Huth',
#  259: 'Benalouane',
#  260: 'Chilwell',
#  261: 'Maguire',
#  262: 'Mahrez',
#  263: 'Albrighton',
#  264: 'Gray',
#  265: 'Amartey',
#  266: 'Mendy',
#  267: 'Ndidi',
#  268: 'Musa',
#  269: 'Iborra',
#  270: 'Vardy',
#  271: 'Okazaki',
#  272: 'Iheanacho',
#  273: 'Jakupovic',
#  274: 'James',
#  275: 'Dragovic',
#  276: 'Choudhury',
#  277: 'Thomas',
#  278: 'Silva',
#  279: 'Diabaté',
#  280: 'Chamberlain',
#  281: 'Mignolet',
#  282: 'Karius',
#  283: 'Lovren',
#  284: 'Moreno',
#  285: 'Clyne',
#  286: 'Gomez',
#  287: 'Matip',
#  288: 'Klavan',
#  289: 'Milner',
#  290: 'Alexander-Arnold',
#  291: 'Lucas',
#  292: 'Henderson',
#  293: 'Coutinho',
#  294: 'Can',
#  295: 'Lallana',
#  296: 'Sheyi Ojo',
#  297: 'Mané',
#  298: 'Grujic',
#  299: 'Wijnaldum',
#  300: 'Woodburn',
#  301: 'Salah',
#  302: 'Firmino',
#  303: 'Ings',
#  304: 'Origi',
#  305: 'Solanke',
#  306: 'van Dijk',
#  307: 'Robertson',
#  308: 'Flanagan',
#  309: 'Ward',
#  310: 'Ederson',
#  311: 'Bravo',
#  312: 'Stones',
#  313: 'Kolarov',
#  314: 'Kompany',
#  315: 'Otamendi',
#  316: 'Delph',
#  317: 'Sterling',
#  318: 'David Silva',
#  319: 'Yaya Touré',
#  320: 'Fernandinho',
#  321: 'Fernando',
#  322: 'De Bruyne',
#  323: 'Gündogan',
#  324: 'Nolito',
#  325: 'Sané',
#  326: 'Bernardo Silva',
#  327: 'Agüero',
#  328: 'Jesus',
#  329: 'Walker',
#  330: 'Danilo',
#  331: 'Mendy',
#  332: 'Foden',
#  333: 'Diaz',
#  334: 'Zinchenko',
#  335: 'Adarabioyo',
#  336: 'Laporte',
#  337: 'Nmecha',
#  338: 'Sánchez',
#  339: 'Matic',
#  340: 'de Gea',
#  341: 'Romero',
#  342: 'Joel Pereira',
#  343: 'Smalling',
#  344: 'Jones',
#  345: 'Shaw',
#  346: 'Rojo',
#  347: 'Valencia',
#  348: 'Darmian',
#  349: 'Blind',
#  350: 'Bailly',
#  351: 'Tuanzebe',
#  352: 'Lindelöf',
#  353: 'Mata',
#  354: 'Fellaini',
#  355: 'Carrick',
#  356: 'Young',
#  357: 'Herrera',
#  358: 'Lingard',
#  359: 'Martial',
#  360: 'Pogba',
#  361: 'McTominay',
#  362: 'Rashford',
#  363: 'Lukaku',
#  364: 'Pereira',
#  365: 'Ibrahimovic',
#  366: 'Kenedy',
#  367: 'Slimani',
#  368: 'Elliot',
#  369: 'Darlow',
#  370: 'Yedlin',
#  371: 'Clark',
#  372: 'Lascelles',
#  373: 'Dummett',
#  374: 'Hanley',
#  375: 'Gámez',
#  376: 'Lejeune',
#  377: 'Ritchie',
#  378: 'Shelvey',
#  379: 'Gouffran',
#  380: 'Diamé',
#  381: 'Colback',
#  382: 'Atsu',
#  383: 'Gayle',
#  384: 'Pérez',
#  385: 'Mitrovic',
#  386: 'Murphy',
#  387: 'Haidara',
#  388: 'de Jong',
#  389: 'Aarons',
#  390: 'Manquillo',
#  391: 'Murphy',
#  392: 'Joselu',
#  393: 'Mbemba',
#  394: 'Merino',
#  395: 'Hayden',
#  396: 'Saivet',
#  397: 'Woodman',
#  398: 'Dubravka',
#  399: 'McCarthy',
#  400: 'Forster',
#  401: 'Bertrand',
#  402: 'Yoshida',
#  403: 'Targett',
#  404: 'Cédric',
#  405: 'Pied',
#  406: 'Stephens',
#  407: 'McQueen',
#  408: 'Bednarek',
#  409: 'Davis',
#  410: 'Ward-Prowse',
#  411: 'Tadic',
#  412: 'Clasie',
#  413: 'Oriol Romeu',
#  414: 'Højbjerg',
#  415: 'Boufal',
#  416: 'Sims',
#  417: 'Redmond',
#  418: 'Long',
#  419: 'Austin',
#  420: 'Gabbiadini',
#  421: 'Lemina',
#  422: 'Taylor',
#  423: 'Hoedt',
#  424: 'Obafemi',
#  425: 'Carrillo',
#  426: 'Zouma',
#  427: 'Butland',
#  428: 'Grant',
#  429: 'Shawcross',
#  430: 'Cameron',
#  431: 'Pieters',
#  432: 'Muniesa',
#  433: 'Johnson',
#  434: 'Tymon',
#  435: 'Allen',
#  436: 'Adam',
#  437: 'Whelan',
#  438: 'Afellay',
#  439: 'Shaqiri',
#  440: 'Imbula',
#  441: 'Bojan',
#  442: 'Sobhi',
#  443: 'Fletcher',
#  444: 'Crouch',
#  445: 'Diouf',
#  446: 'Berahino',
#  447: 'Wimmer',
#  448: 'Choupo-Moting',
#  449: 'Jesé',
#  450: 'Martins Indi',
#  451: 'Souttar',
#  452: 'Edwards',
#  453: 'Ngoy',
#  454: 'Haugaard',
#  455: 'Ireland',
#  456: 'Bauer',
#  457: 'Stafylidis',
#  458: 'Badou Ndiaye',
#  459: 'Campbell',
#  460: 'King',
#  461: 'Fabianski',
#  462: 'Nordfeldt',
#  463: 'Naughton',
#  464: 'Rangel',
#  465: 'Fernández',
#  466: 'Kingsley',
#  467: 'van der Hoorn',
#  468: 'Mawson',
#  469: 'Olsson',
#  470: 'Routledge',
#  471: 'Britton',
#  472: 'Fulton',
#  473: 'Ki Sung-yueng',
#  474: 'Montero',
#  475: 'Fer',
#  476: 'Dyer',
#  477: 'Carroll',
#  478: 'Barrow',
#  479: 'Narsingh',
#  480: 'Mesa',
#  481: 'McBurnie',
#  482: 'Jordan Ayew',
#  483: 'Abraham',
#  484: 'André Ayew',
#  485: 'Bartley',
#  486: 'Clucas',
#  487: 'Sanches',
#  488: 'Bony',
#  489: 'Rodon',
#  490: 'Mulder',
#  491: 'Roberts',
#  492: 'Llorente',
#  493: 'Lloris',
#  494: 'Vorm',
#  495: 'Alderweireld',
#  496: 'Rose',
#  497: 'Vertonghen',
#  498: 'Davies',
#  499: 'Trippier',
#  500: 'Dier',
#  501: 'Dembélé',
#  502: 'Lamela',
#  503: 'Eriksen',
#  504: 'Alli',
#  505: 'Wanyama',
#  506: 'Son',
#  507: 'Winks',
#  508: 'Sissoko',
#  509: 'Kane',
#  510: 'Janssen',
#  511: 'Walker-Peters',
#  512: 'Carter-Vickers',
#  513: 'Sánchez',
#  514: 'Oakley-Boothe',
#  515: 'Aurier',
#  516: 'Foyth',
#  517: 'Gazzaniga',
#  518: 'Whiteman',
#  519: 'Lucas Moura',
#  520: 'Gray',
#  521: 'Chalobah',
#  522: 'Wagué',
#  523: 'Pantilimon',
#  524: 'Gomes',
#  525: 'Kaboul',
#  526: 'Cathcart',
#  527: 'Prödl',
#  528: 'Holebas',
#  529: 'Britos',
#  530: 'Kabasele',
#  531: 'Janmaat',
#  532: 'Mariappa',
#  533: 'Mason',
#  534: 'Kiko Femenía',
#  535: 'Cleverley',
#  536: 'Capoue',
#  537: 'Behrami',
#  538: 'Berghuis',
#  539: 'Amrabat',
#  540: 'Success',
#  541: 'Doucouré',
#  542: 'Pereyra',
#  543: 'Hughes',
#  544: 'Deeney',
#  545: 'Okaka',
#  546: 'Zárate',
#  547: 'Watson',
#  548: 'Sinclair',
#  549: 'Richarlison',
#  550: 'Carrillo',
#  551: 'Karnezis',
#  552: 'Zeegelaar',
#  553: 'Folivi',
#  554: 'Bachmann',
#  555: 'Deulofeu',
#  556: 'Stewart',
#  557: 'Lukebakio',
#  558: 'Ndong',
#  559: 'Mukena',
#  560: 'Gibbs',
#  561: 'Barry',
#  562: 'Sturridge',
#  563: 'Myhill',
#  564: 'Foster',
#  565: 'Nyom',
#  566: 'Evans',
#  567: 'Dawson',
#  568: 'McAuley',
#  569: 'Livermore',
#  570: 'Chadli',
#  571: 'Morrison',
#  572: 'Yacob',
#  573: 'McClean',
#  574: 'Leko',
#  575: 'Phillips',
#  576: 'Field',
#  577: 'Brunt',
#  578: 'Rondón',
#  579: 'Robson-Kanu',
#  580: 'Rodriguez',
#  581: 'Hegazi',
#  582: 'Harper',
#  583: 'Wilson',
#  584: 'Burke',
#  585: 'Krychowiak',
#  586: 'Palmer',
#  587: 'Melbourne',
#  588: 'Tulloch',
#  589: 'Ferguson',
#  590: 'Gabr',
#  591: 'Jameson',
#  592: 'Arnautovic',
#  593: 'Adrián',
#  594: 'Randolph',
#  595: 'Fonte',
#  596: 'Collins',
#  597: 'Reid',
#  598: 'Cresswell',
#  599: 'Ogbonna',
#  600: 'Byram',
#  601: 'Masuaku',
#  602: 'Zabaleta',
#  603: 'Snodgrass',
#  604: 'Noble',
#  605: 'Kouyaté',
#  606: 'Obiang',
#  607: 'Lanzini',
#  608: 'Antonio',
#  609: 'Feghouli',
#  610: 'Fernandes',
#  611: 'Carroll',
#  612: 'Sakho',
#  613: 'Fletcher',
#  614: 'Valencia',
#  615: 'Hart',
#  616: 'Chicharito',
#  617: 'Rice',
#  618: 'Haksabanovic',
#  619: 'Martínez',
#  620: 'Quina',
#  621: 'Johnson',
#  622: 'Trott',
#  623: 'Makasi',
#  624: 'Burke',
#  625: 'Cullen',
#  626: 'João Mário',
#  627: 'Oxford',
#  628: 'Hugill',
#  629: 'Evra'}

# %%
dict_players = {}
for n in range(len(player_ids)):
    name = player_ids[n]['web_name']
    dict_players[n] = name

# %%
i = 327
aguero = requests.get('https://fantasy.premierleague.com/drf/element-summary/'+str(i)).json()

# %%
def player_data(i):
    return requests.get('https://fantasy.premierleague.com/drf/element-summary/'+str(i+1)).json()

# %%
aguero['history']
# Out:
# [{'assists': 0,
#   'attempted_passes': 13,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': -1,
#   'clean_sheets': 1,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 11,
#   'creativity': '5.3',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 6,
#   'fouls': 2,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '1.2',
#   'id': 327,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-08-12T14:00:00Z',
#   'kickoff_time_formatted': '12 Aug 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 68,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 16,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 2,
#   'red_cards': 0,
#   'round': 1,
#   'saves': 0,
#   'selected': 264048,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 5,
#   'team_a_score': 0,
#   'team_h_score': 0,
#   'threat': '20.0',
#   'total_points': 2,
#   'transfers_balance': 0,
#   'transfers_in': 0,
#   'transfers_out': 0,
#   'value': 70,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 22,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 1,
#   'bps': 27,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 19,
#   'creativity': '8.9',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 15,
#   'fouls': 1,
#   'goals_conceded': 2,
#   'goals_scored': 1,
#   'ict_index': '6.4',
#   'id': 838,
#   'influence': '30.8',
#   'key_passes': 0,
#   'kickoff_time': '2017-08-19T14:00:00Z',
#   'kickoff_time_formatted': '19 Aug 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 79,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 20,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 2,
#   'saves': 0,
#   'selected': 242865,
#   'tackled': 1,
#   'tackles': 0,
#   'target_missed': 1,
#   'team_a_score': 2,
#   'team_h_score': 3,
#   'threat': '24.0',
#   'total_points': 7,
#   'transfers_balance': -34146,
#   'transfers_in': 10026,
#   'transfers_out': 44172,
#   'value': 70,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 15,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 9,
#   'clean_sheets': 1,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 6,
#   'creativity': '16.8',
#   'dribbles': 1,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 24,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '3.4',
#   'id': 1354,
#   'influence': '8.0',
#   'key_passes': 1,
#   'kickoff_time': '2017-08-26T14:00:00Z',
#   'kickoff_time_formatted': '26 Aug 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 70,
#   'offside': 1,
#   'open_play_crosses': 0,
#   'opponent_team': 8,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 2,
#   'red_cards': 0,
#   'round': 3,
#   'saves': 0,
#   'selected': 276893,
#   'tackled': 0,
#   'tackles': 1,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 0,
#   'threat': '9.0',
#   'total_points': 2,
#   'transfers_balance': 23296,
#   'transfers_in': 51566,
#   'transfers_out': 28270,
#   'value': 70,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 7,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 5,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 5,
#   'creativity': '1.3',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 36,
#   'fouls': 0,
#   'goals_conceded': 2,
#   'goals_scored': 0,
#   'ict_index': '0.3',
#   'id': 1885,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-09-09T14:00:00Z',
#   'kickoff_time_formatted': '09 Sep 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 68,
#   'offside': 1,
#   'open_play_crosses': 0,
#   'opponent_team': 18,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 4,
#   'saves': 0,
#   'selected': 263038,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 2,
#   'team_h_score': 0,
#   'threat': '2.0',
#   'total_points': 2,
#   'transfers_balance': -19720,
#   'transfers_in': 29369,
#   'transfers_out': 49089,
#   'value': 70,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 3,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 42,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 2429,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-09-16T11:30:00Z',
#   'kickoff_time_formatted': '16 Sep 12:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 1,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 6,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 5,
#   'saves': 0,
#   'selected': 209094,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': -55582,
#   'transfers_in': 9018,
#   'transfers_out': 64600,
#   'value': 70,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 4,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 3,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 2,
#   'creativity': '0.3',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 55,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 2975,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-09-23T14:00:00Z',
#   'kickoff_time_formatted': '23 Sep 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 17,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 12,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 1,
#   'red_cards': 0,
#   'round': 6,
#   'saves': 0,
#   'selected': 142112,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': -68106,
#   'transfers_in': 4493,
#   'transfers_out': 72599,
#   'value': 68,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 5,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 3,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 5,
#   'creativity': '11.8',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 65,
#   'fouls': 0,
#   'goals_conceded': 1,
#   'goals_scored': 0,
#   'ict_index': '2.4',
#   'id': 3525,
#   'influence': '2.2',
#   'key_passes': 1,
#   'kickoff_time': '2017-09-30T14:00:00Z',
#   'kickoff_time_formatted': '30 Sep 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 23,
#   'offside': 1,
#   'open_play_crosses': 0,
#   'opponent_team': 15,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 7,
#   'saves': 0,
#   'selected': 108602,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 2,
#   'threat': '10.0',
#   'total_points': 1,
#   'transfers_balance': -34024,
#   'transfers_in': 2728,
#   'transfers_out': 36752,
#   'value': 67,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 12,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 3,
#   'bps': 46,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 10,
#   'creativity': '2.8',
#   'dribbles': 1,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 77,
#   'fouls': 4,
#   'goals_conceded': 2,
#   'goals_scored': 2,
#   'ict_index': '9.9',
#   'id': 4079,
#   'influence': '62.4',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-15T15:00:00Z',
#   'kickoff_time_formatted': '15 Oct 16:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 1,
#   'open_play_crosses': 0,
#   'opponent_team': 13,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 1,
#   'red_cards': 0,
#   'round': 8,
#   'saves': 0,
#   'selected': 95831,
#   'tackled': 1,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 2,
#   'team_h_score': 2,
#   'threat': '34.0',
#   'total_points': 12,
#   'transfers_balance': -13344,
#   'transfers_in': 4776,
#   'transfers_out': 18120,
#   'value': 67,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 1},
#  {'assists': 0,
#   'attempted_passes': 22,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 5,
#   'clean_sheets': 1,
#   'clearances_blocks_interceptions': 2,
#   'completed_passes': 15,
#   'creativity': '13.8',
#   'dribbles': 1,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 86,
#   'fouls': 1,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '5.0',
#   'id': 4636,
#   'influence': '5.6',
#   'key_passes': 1,
#   'kickoff_time': '2017-10-21T16:30:00Z',
#   'kickoff_time_formatted': '21 Oct 17:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 1,
#   'open_play_crosses': 0,
#   'opponent_team': 19,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 2,
#   'red_cards': 0,
#   'round': 9,
#   'saves': 0,
#   'selected': 148377,
#   'tackled': 1,
#   'tackles': 0,
#   'target_missed': 1,
#   'team_a_score': 0,
#   'team_h_score': 1,
#   'threat': '31.0',
#   'total_points': 2,
#   'transfers_balance': 50909,
#   'transfers_in': 57347,
#   'transfers_out': 6438,
#   'value': 66,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 11,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 4,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 8,
#   'creativity': '3.6',
#   'dribbles': 1,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 93,
#   'fouls': 0,
#   'goals_conceded': 1,
#   'goals_scored': 0,
#   'ict_index': '4.1',
#   'id': 5195,
#   'influence': '1.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-29T13:30:00Z',
#   'kickoff_time_formatted': '29 Oct 13:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 1,
#   'open_play_crosses': 0,
#   'opponent_team': 3,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 10,
#   'saves': 0,
#   'selected': 169224,
#   'tackled': 2,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 1,
#   'threat': '36.0',
#   'total_points': 2,
#   'transfers_balance': 19165,
#   'transfers_in': 35949,
#   'transfers_out': 16784,
#   'value': 66,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 6,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 3,
#   'clean_sheets': 1,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 3,
#   'creativity': '11.8',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 105,
#   'fouls': 1,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '1.6',
#   'id': 5758,
#   'influence': '0.2',
#   'key_passes': 1,
#   'kickoff_time': '2017-11-04T15:00:00Z',
#   'kickoff_time_formatted': '04 Nov 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 64,
#   'offside': 2,
#   'open_play_crosses': 0,
#   'opponent_team': 4,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 11,
#   'saves': 0,
#   'selected': 167589,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 1,
#   'team_a_score': 1,
#   'team_h_score': 0,
#   'threat': '4.0',
#   'total_points': 2,
#   'transfers_balance': -2716,
#   'transfers_in': 15756,
#   'transfers_out': 18472,
#   'value': 66,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 4,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 3,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 2,
#   'creativity': '0.3',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 117,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 6324,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-18T15:00:00Z',
#   'kickoff_time_formatted': '18 Nov 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 11,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 10,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 1,
#   'red_cards': 0,
#   'round': 12,
#   'saves': 0,
#   'selected': 146180,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 3,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': -22307,
#   'transfers_in': 6858,
#   'transfers_out': 29165,
#   'value': 66,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 126,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 6893,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-26T13:30:00Z',
#   'kickoff_time_formatted': '26 Nov 13:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 7,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 13,
#   'saves': 0,
#   'selected': 138609,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 4,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -8099,
#   'transfers_in': 10311,
#   'transfers_out': 18410,
#   'value': 66,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 139,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 7463,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-29T20:00:00Z',
#   'kickoff_time_formatted': '29 Nov 20:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 11,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 14,
#   'saves': 0,
#   'selected': 118167,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -20676,
#   'transfers_in': 2520,
#   'transfers_out': 23196,
#   'value': 66,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 3,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 142,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.2',
#   'id': 8034,
#   'influence': '2.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-03T13:30:00Z',
#   'kickoff_time_formatted': '03 Dec 13:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 5,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 2,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 15,
#   'saves': 0,
#   'selected': 105547,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': -12863,
#   'transfers_in': 1605,
#   'transfers_out': 14468,
#   'value': 65,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 1,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 2,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 1,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 160,
#   'fouls': 1,
#   'goals_conceded': 1,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 8608,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-10T12:00:00Z',
#   'kickoff_time_formatted': '10 Dec 12:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 4,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 1,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 16,
#   'saves': 0,
#   'selected': 95723,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': -10052,
#   'transfers_in': 837,
#   'transfers_out': 10889,
#   'value': 65,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 13,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 1,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 12,
#   'creativity': '5.1',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 168,
#   'fouls': 0,
#   'goals_conceded': 1,
#   'goals_scored': 0,
#   'ict_index': '0.6',
#   'id': 9185,
#   'influence': '1.2',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-13T19:45:00Z',
#   'kickoff_time_formatted': '13 Dec 19:45',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 45,
#   'offside': 1,
#   'open_play_crosses': 0,
#   'opponent_team': 9,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 2,
#   'red_cards': 0,
#   'round': 17,
#   'saves': 0,
#   'selected': 89950,
#   'tackled': 1,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 4,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': -5890,
#   'transfers_in': 452,
#   'transfers_out': 6342,
#   'value': 64,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 9,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 4,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 5,
#   'creativity': '1.6',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 174,
#   'fouls': 1,
#   'goals_conceded': 1,
#   'goals_scored': 0,
#   'ict_index': '0.5',
#   'id': 9763,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-16T15:00:00Z',
#   'kickoff_time_formatted': '16 Dec 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 60,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 5,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 18,
#   'saves': 0,
#   'selected': 85190,
#   'tackled': 1,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 1,
#   'threat': '4.0',
#   'total_points': 2,
#   'transfers_balance': -4866,
#   'transfers_in': 255,
#   'transfers_out': 5121,
#   'value': 64,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 4,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 3,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 1,
#   'creativity': '1.1',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 187,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.3',
#   'id': 10343,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-23T15:00:00Z',
#   'kickoff_time_formatted': '23 Dec 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 11,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 8,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 1,
#   'red_cards': 0,
#   'round': 19,
#   'saves': 0,
#   'selected': 83719,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 1,
#   'threat': '2.0',
#   'total_points': 1,
#   'transfers_balance': -1751,
#   'transfers_in': 2117,
#   'transfers_out': 3868,
#   'value': 64,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 6,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 1,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 3,
#   'creativity': '1.3',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 198,
#   'fouls': 1,
#   'goals_conceded': 1,
#   'goals_scored': 0,
#   'ict_index': '0.3',
#   'id': 10928,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-26T12:30:00Z',
#   'kickoff_time_formatted': '26 Dec 12:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 27,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 17,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 20,
#   'saves': 0,
#   'selected': 83299,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 1,
#   'team_a_score': 2,
#   'team_h_score': 5,
#   'threat': '5.0',
#   'total_points': 1,
#   'transfers_balance': -608,
#   'transfers_in': 2784,
#   'transfers_out': 3392,
#   'value': 64,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 3,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 3,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 2,
#   'creativity': '1.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 206,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.3',
#   'id': 11514,
#   'influence': '2.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-30T17:30:00Z',
#   'kickoff_time_formatted': '30 Dec 17:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 10,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 12,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 2,
#   'red_cards': 0,
#   'round': 21,
#   'saves': 0,
#   'selected': 80870,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': -2643,
#   'transfers_in': 1770,
#   'transfers_out': 4413,
#   'value': 63,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 1,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 2,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 1,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 217,
#   'fouls': 1,
#   'goals_conceded': 1,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 12040,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-01-02T19:45:00Z',
#   'kickoff_time_formatted': '02 Jan 19:45',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 15,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 6,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 22,
#   'saves': 0,
#   'selected': 81414,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 2,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': 437,
#   'transfers_in': 2886,
#   'transfers_out': 2449,
#   'value': 63,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 229,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 12692,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-01-13T15:00:00Z',
#   'kickoff_time_formatted': '13 Jan 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 18,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 23,
#   'saves': 0,
#   'selected': 78707,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 2,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -2996,
#   'transfers_in': 1851,
#   'transfers_out': 4847,
#   'value': 63,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 16,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 8,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 11,
#   'creativity': '17.8',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 237,
#   'fouls': 0,
#   'goals_conceded': 1,
#   'goals_scored': 0,
#   'ict_index': '4.6',
#   'id': 13290,
#   'influence': '10.4',
#   'key_passes': 1,
#   'kickoff_time': '2018-01-21T16:00:00Z',
#   'kickoff_time_formatted': '21 Jan 16:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 81,
#   'offside': 1,
#   'open_play_crosses': 0,
#   'opponent_team': 17,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 1,
#   'red_cards': 0,
#   'round': 24,
#   'saves': 0,
#   'selected': 75896,
#   'tackled': 0,
#   'tackles': 1,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 1,
#   'threat': '18.0',
#   'total_points': 2,
#   'transfers_balance': -2930,
#   'transfers_in': 699,
#   'transfers_out': 3629,
#   'value': 63,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 4,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': -1,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 3,
#   'creativity': '0.1',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 248,
#   'fouls': 1,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 13893,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-01-31T19:45:00Z',
#   'kickoff_time_formatted': '31 Jan 19:45',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 11,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 3,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 1,
#   'red_cards': 0,
#   'round': 25,
#   'saves': 0,
#   'selected': 77121,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': 963,
#   'transfers_in': 3294,
#   'transfers_out': 2331,
#   'value': 63,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 1},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 260,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 14506,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-02-03T15:00:00Z',
#   'kickoff_time_formatted': '03 Feb 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 19,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 26,
#   'saves': 0,
#   'selected': 73614,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 3,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -3549,
#   'transfers_in': 149,
#   'transfers_out': 3698,
#   'value': 63,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 266,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 15131,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-02-11T16:30:00Z',
#   'kickoff_time_formatted': '11 Feb 16:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 10,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 27,
#   'saves': 0,
#   'selected': 72035,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 2,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -1683,
#   'transfers_in': 380,
#   'transfers_out': 2063,
#   'value': 62,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 2,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 3,
#   'bps': 26,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 1,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 327,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 274,
#   'fouls': 0,
#   'goals_conceded': 0,
#   'goals_scored': 1,
#   'ict_index': '5.0',
#   'id': 15758,
#   'influence': '33.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-02-24T15:00:00Z',
#   'kickoff_time_formatted': '24 Feb 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 9,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 4,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'recoveries': 1,
#   'red_cards': 0,
#   'round': 28,
#   'saves': 0,
#   'selected': 71162,
#   'tackled': 1,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 1,
#   'threat': '17.0',
#   'total_points': 8,
#   'transfers_balance': -1112,
#   'transfers_in': 430,
#   'transfers_out': 1542,
#   'value': 62,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0}]

# %%
row = {'id':393,'player': dict_players[393]}
for n in range(len(fields)):
    row[fields[n]] = kane['history'][0][fields[n]]

# %%
row
# Out:
# {'assists': 0,
#  'attempted_passes': 16,
#  'big_chances_created': 0,
#  'big_chances_missed': 2,
#  'bonus': 0,
#  'bps': -6,
#  'clean_sheets': 1,
#  'clearances_blocks_interceptions': 1,
#  'completed_passes': 15,
#  'creativity': '30.6',
#  'dribbles': 1,
#  'ea_index': 0,
#  'element': 394,
#  'errors_leading_to_goal': 0,
#  'errors_leading_to_goal_attempt': 0,
#  'fixture': 10,
#  'fouls': 1,
#  'goals_conceded': 0,
#  'goals_scored': 0,
#  'ict_index': '12.2',
#  'id': 394,
#  'influence': '4.0',
#  'key_passes': 2,
#  'kickoff_time': '2017-08-13T12:30:00Z',
#  'kickoff_time_formatted': '13 Aug 13:30',
#  'loaned_in': 0,
#  'loaned_out': 0,
#  'minutes': 90,
#  'offside': 0,
#  'open_play_crosses': 0,
#  'opponent_team': 13,
#  'own_goals': 0,
#  'penalties_conceded': 0,
#  'penalties_missed': 0,
#  'penalties_saved': 0,
#  'player': 'Mbemba',
#  'recoveries': 2,
#  'red_cards': 0,
#  'round': 1,
#  'saves': 0,
#  'selected': 1473220,
#  'tackled': 3,
#  'tackles': 0,
#  'target_missed': 2,
#  'team_a_score': 2,
#  'team_h_score': 0,
#  'threat': '87.0',
#  'total_points': 1,
#  'transfers_balance': 0,
#  'transfers_in': 0,
#  'transfers_out': 0,
#  'value': 125,
#  'was_home': False,
#  'winning_goals': 0,
#  'yellow_cards': 1}

# %%
import pandas as pd
import numpy as np
import requests
from time import sleep

# %%
# get list of player_ids
player_ids = requests.get('https://fantasy.premierleague.com/drf/elements/').json()

# %%
# dictionary put together by looping ids and player names
dict_players = {}
for n in range(len(player_ids)):
    name = player_ids[n]['web_name']
    dict_players[n] = name

# %%
#create function to return json object for given integer representing player id
def player_data(i):
    return requests.get('https://fantasy.premierleague.com/drf/element-summary/'+str(i+1)).json()

# %%
# save field names (from url)
fields = [u'transfers_out', u'yellow_cards', u'tackles', u'goals_conceded',
u'winning_goals', u'errors_leading_to_goal_attempt', u'saves', u'influence', u'key_passes',
u'transfers_in', u'transfers_balance', u'goals_scored', u'id', u'own_goals', u'team_h_score',
u'selected', u'creativity', u'kickoff_time_formatted', u'bonus', u'big_chances_created',
u'ict_index', u'total_points', u'penalties_missed', u'attempted_passes', u'opponent_team',
u'completed_passes', u'target_missed', u'errors_leading_to_goal', u'loaned_in', u'fixture',
u'was_home', u'recoveries', u'clean_sheets', u'assists', u'team_a_score', u'open_play_crosses',
u'clearances_blocks_interceptions', u'penalties_conceded', u'offside', u'ea_index', u'kickoff_time',
u'penalties_saved', u'fouls', u'red_cards', u'loaned_out', u'value', u'element', u'bps', u'dribbles',
u'threat', u'tackled', u'big_chances_missed', u'minutes', u'round']

# %%
# set values
latest_gw = 28
fpl_data = []

# %%
# create list of dictionaries
for playerid in range(len(dict_players)): # for each player
    fplurl = player_data(playerid) # save url for their data
    for week in range(latest_gw): # loop through all available gameweeks
        # generate row of data
        row = {'fpl_id': playerid, 'player': dict_players[playerid]}
        for n in range(len(fields)): # grab data on each field and add to dict
            row[fields[n]] = fplurl['history'][week][fields[n]]
        fpl_data.append(row) # add to list
    print (dict_players[playerid] + ' done..')
    sleep(0.1) # to not overload websites
# Out:
# Ospina done..
# Cech done..
# Martinez done..
# Koscielny done..
# Mertesacker done..
# Gabriel done..
# Bellerín done..
# Jenkinson done..
# Monreal done..
# Holding done..
# Mustafi done..
# Kolasinac done..
# Özil done..
# Cazorla done..
# Ramsey done..
# Coquelin done..
# Iwobi done..
# Elneny done..
# Xhaka done..
# Wilshere done..
# Welbeck done..
# Pérez done..
# Lacazette done..
# Mkhitaryan done..
# Chambers done..
# Nelson done..
# Maitland-Niles done..
# Macey done..
# Nketiah done..
# Debuchy done..
# Mavropanos done..
# Aubameyang done..
# Begovic done..
# Boruc done..
# Federici done..
# Francis done..
# Steve Cook done..
# Daniels done..
# Adam Smith done..
# Mings done..
# Brad Smith done..
# Aké done..
# Arter done..
# Pugh done..
# Surman done..
# Stanislas done..
# Gosling done..
# Gradel done..
# Ibe done..
# Lewis Cook done..
# Fraser done..
# Wilson done..
# Afobe done..
# Mousset done..
# King done..
# Defoe done..
# Ramsdale done..
# Simpson done..
# Hyndman done..
# Mahoney done..
# Butcher done..
# Taylor done..
# Mäenpää done..
# Ryan done..
# Dunk done..
# Duffy done..
# Hünemeier done..
# Bruno done..
# Bong done..
# Rosenior done..
# Goldson done..
# Knockaert done..
# Stephens done..
# Kayal done..
# Sidwell done..
# March done..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-089d73333beb> in <module>()
#       9         fpl_data.append(row) # add to list
#      10     print (dict_players[playerid] + ' done..')
# ---> 11     sleep(0.1) # to not overload websites
#
# KeyboardInterrupt:

# %%
fpl_data
# Out:
# [{'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 1,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 1,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-08-11T18:45:00Z',
#   'kickoff_time_formatted': '11 Aug 19:45',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 9,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 1,
#   'saves': 0,
#   'selected': 8964,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 3,
#   'team_h_score': 4,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': 0,
#   'transfers_in': 0,
#   'transfers_out': 0,
#   'value': 50,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 16,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 512,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-08-19T16:30:00Z',
#   'kickoff_time_formatted': '19 Aug 17:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 15,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 2,
#   'saves': 0,
#   'selected': 11030,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -1128,
#   'transfers_in': 195,
#   'transfers_out': 1323,
#   'value': 50,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 28,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 1028,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-08-27T15:00:00Z',
#   'kickoff_time_formatted': '27 Aug 16:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 10,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 3,
#   'saves': 0,
#   'selected': 11243,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 4,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -982,
#   'transfers_in': 106,
#   'transfers_out': 1088,
#   'value': 50,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 31,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 1559,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-09-09T14:00:00Z',
#   'kickoff_time_formatted': '09 Sep 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 2,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 4,
#   'saves': 0,
#   'selected': 11534,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 3,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -730,
#   'transfers_in': 155,
#   'transfers_out': 885,
#   'value': 49,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 49,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 2103,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-09-17T12:30:00Z',
#   'kickoff_time_formatted': '17 Sep 13:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 5,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 5,
#   'saves': 0,
#   'selected': 11566,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -441,
#   'transfers_in': 75,
#   'transfers_out': 516,
#   'value': 49,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 60,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 2649,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-09-25T19:00:00Z',
#   'kickoff_time_formatted': '25 Sep 20:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 19,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 6,
#   'saves': 0,
#   'selected': 11539,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -425,
#   'transfers_in': 147,
#   'transfers_out': 572,
#   'value': 49,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 68,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 3199,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-01T11:00:00Z',
#   'kickoff_time_formatted': '01 Oct 12:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 3,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 7,
#   'saves': 0,
#   'selected': 11534,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -354,
#   'transfers_in': 119,
#   'transfers_out': 473,
#   'value': 49,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 80,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 3753,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-14T16:30:00Z',
#   'kickoff_time_formatted': '14 Oct 17:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 18,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 8,
#   'saves': 0,
#   'selected': 11589,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -300,
#   'transfers_in': 138,
#   'transfers_out': 438,
#   'value': 49,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 82,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 4310,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-22T12:30:00Z',
#   'kickoff_time_formatted': '22 Oct 13:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 7,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 9,
#   'saves': 0,
#   'selected': 11512,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 5,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -202,
#   'transfers_in': 66,
#   'transfers_out': 268,
#   'value': 49,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 91,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 4869,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-28T14:00:00Z',
#   'kickoff_time_formatted': '28 Oct 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 16,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 10,
#   'saves': 0,
#   'selected': 11027,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -530,
#   'transfers_in': 39,
#   'transfers_out': 569,
#   'value': 49,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 110,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 5432,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-05T14:15:00Z',
#   'kickoff_time_formatted': '05 Nov 14:15',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 11,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 11,
#   'saves': 0,
#   'selected': 10761,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 3,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -312,
#   'transfers_in': 20,
#   'transfers_out': 332,
#   'value': 49,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 111,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 5998,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-18T12:30:00Z',
#   'kickoff_time_formatted': '18 Nov 12:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 17,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 12,
#   'saves': 0,
#   'selected': 10611,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -243,
#   'transfers_in': 21,
#   'transfers_out': 264,
#   'value': 48,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 130,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 6567,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-26T14:00:00Z',
#   'kickoff_time_formatted': '26 Nov 14:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 4,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 13,
#   'saves': 0,
#   'selected': 10686,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -51,
#   'transfers_in': 47,
#   'transfers_out': 98,
#   'value': 48,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 135,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 7137,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-29T19:45:00Z',
#   'kickoff_time_formatted': '29 Nov 19:45',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 8,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 14,
#   'saves': 0,
#   'selected': 10704,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 5,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -63,
#   'transfers_in': 36,
#   'transfers_out': 99,
#   'value': 48,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 141,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 7708,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-02T17:30:00Z',
#   'kickoff_time_formatted': '02 Dec 17:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 12,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 15,
#   'saves': 0,
#   'selected': 10741,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 3,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -57,
#   'transfers_in': 39,
#   'transfers_out': 96,
#   'value': 48,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 160,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 8282,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-10T12:00:00Z',
#   'kickoff_time_formatted': '10 Dec 12:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 14,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 16,
#   'saves': 0,
#   'selected': 10822,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -89,
#   'transfers_in': 44,
#   'transfers_out': 133,
#   'value': 48,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 170,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 8859,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-13T20:00:00Z',
#   'kickoff_time_formatted': '13 Dec 20:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 20,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 17,
#   'saves': 0,
#   'selected': 10832,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -76,
#   'transfers_in': 28,
#   'transfers_out': 104,
#   'value': 48,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 171,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 9437,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-16T15:00:00Z',
#   'kickoff_time_formatted': '16 Dec 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 13,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 18,
#   'saves': 0,
#   'selected': 10875,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -61,
#   'transfers_in': 28,
#   'transfers_out': 89,
#   'value': 48,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 181,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 10017,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-22T19:45:00Z',
#   'kickoff_time_formatted': '22 Dec 19:45',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 10,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 19,
#   'saves': 0,
#   'selected': 10927,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 3,
#   'team_h_score': 3,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -85,
#   'transfers_in': 48,
#   'transfers_out': 133,
#   'value': 48,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 193,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 10602,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-28T20:00:00Z',
#   'kickoff_time_formatted': '28 Dec 20:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 6,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 20,
#   'saves': 0,
#   'selected': 10945,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 3,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -77,
#   'transfers_in': 48,
#   'transfers_out': 125,
#   'value': 48,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 210,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 11188,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-31T16:30:00Z',
#   'kickoff_time_formatted': '31 Dec 16:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 19,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 21,
#   'saves': 0,
#   'selected': 10933,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -110,
#   'transfers_in': 51,
#   'transfers_out': 161,
#   'value': 48,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 211,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 11714,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-01-03T19:45:00Z',
#   'kickoff_time_formatted': '03 Jan 19:45',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 5,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 22,
#   'saves': 0,
#   'selected': 10950,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 2,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -32,
#   'transfers_in': 31,
#   'transfers_out': 63,
#   'value': 48,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 221,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 12366,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-01-14T13:30:00Z',
#   'kickoff_time_formatted': '14 Jan 13:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 2,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 23,
#   'saves': 0,
#   'selected': 11038,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -99,
#   'transfers_in': 59,
#   'transfers_out': 158,
#   'value': 48,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 231,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 12964,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-01-20T15:00:00Z',
#   'kickoff_time_formatted': '20 Jan 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 6,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 24,
#   'saves': 0,
#   'selected': 11075,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 4,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -82,
#   'transfers_in': 40,
#   'transfers_out': 122,
#   'value': 48,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 242,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 13567,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-01-30T19:45:00Z',
#   'kickoff_time_formatted': '30 Jan 19:45',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 16,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 25,
#   'saves': 0,
#   'selected': 11124,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 3,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -70,
#   'transfers_in': 85,
#   'transfers_out': 155,
#   'value': 48,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 8,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 6,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 7,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 251,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.5',
#   'id': 14180,
#   'influence': '5.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-02-03T17:30:00Z',
#   'kickoff_time_formatted': '03 Feb 17:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 20,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 7,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 4,
#   'red_cards': 0,
#   'round': 26,
#   'saves': 1,
#   'selected': 11137,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 5,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': -54,
#   'transfers_in': 26,
#   'transfers_out': 80,
#   'value': 48,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 269,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 14805,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-02-10T12:30:00Z',
#   'kickoff_time_formatted': '10 Feb 12:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 17,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 27,
#   'saves': 0,
#   'selected': 11522,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': 215,
#   'transfers_in': 345,
#   'transfers_out': 130,
#   'value': 48,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 1,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 271,
#   'fouls': 0,
#   'fpl_id': 0,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 15432,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2018-03-01T19:45:00Z',
#   'kickoff_time_formatted': '01 Mar 19:45',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 11,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Ospina',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 28,
#   'saves': 0,
#   'selected': 11563,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 3,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -153,
#   'transfers_in': 57,
#   'transfers_out': 210,
#   'value': 48,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 20,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 9,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 16,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 1,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 3,
#   'goals_scored': 0,
#   'ict_index': '1.2',
#   'id': 2,
#   'influence': '12.2',
#   'key_passes': 0,
#   'kickoff_time': '2017-08-11T18:45:00Z',
#   'kickoff_time_formatted': '11 Aug 19:45',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 9,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Cech',
#   'recoveries': 4,
#   'red_cards': 0,
#   'round': 1,
#   'saves': 0,
#   'selected': 222249,
#   'tackled': 0,
#   'tackles': 1,
#   'target_missed': 0,
#   'team_a_score': 3,
#   'team_h_score': 4,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': 0,
#   'transfers_in': 0,
#   'transfers_out': 0,
#   'value': 55,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 18,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 14,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 16,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 16,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 1,
#   'goals_scored': 0,
#   'ict_index': '2.6',
#   'id': 513,
#   'influence': '25.8',
#   'key_passes': 0,
#   'kickoff_time': '2017-08-19T16:30:00Z',
#   'kickoff_time_formatted': '19 Aug 17:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 15,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Cech',
#   'recoveries': 7,
#   'red_cards': 0,
#   'round': 2,
#   'saves': 3,
#   'selected': 262457,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 3,
#   'transfers_balance': -12409,
#   'transfers_in': 4337,
#   'transfers_out': 16746,
#   'value': 55,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 18,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 23,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 4,
#   'completed_passes': 12,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 28,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 4,
#   'goals_scored': 0,
#   'ict_index': '5.8',
#   'id': 1029,
#   'influence': '58.4',
#   'key_passes': 0,
#   'kickoff_time': '2017-08-27T15:00:00Z',
#   'kickoff_time_formatted': '27 Aug 16:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 10,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Cech',
#   'recoveries': 10,
#   'red_cards': 0,
#   'round': 3,
#   'saves': 6,
#   'selected': 261327,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 4,
#   'threat': '0.0',
#   'total_points': 2,
#   'transfers_balance': -18456,
#   'transfers_in': 1931,
#   'transfers_out': 20387,
#   'value': 55,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 32,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 25,
#   'clean_sheets': 1,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 16,
#   'creativity': '0.0',
#   'dribbles': 1,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 31,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '2.0',
#   'id': 1560,
#   'influence': '19.6',
#   'key_passes': 0,
#   'kickoff_time': '2017-09-09T14:00:00Z',
#   'kickoff_time_formatted': '09 Sep 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 2,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Cech',
#   'recoveries': 6,
#   'red_cards': 0,
#   'round': 4,
#   'saves': 2,
#   'selected': 262836,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 3,
#   'threat': '0.0',
#   'total_points': 6,
#   'transfers_balance': -14720,
#   'transfers_in': 5428,
#   'transfers_out': 20148,
#   'value': 55,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 30,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 3,
#   'bps': 30,
#   'clean_sheets': 1,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 18,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 49,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '3.1',
#   'id': 2104,
#   'influence': '30.8',
#   'key_passes': 0,
#   'kickoff_time': '2017-09-17T12:30:00Z',
#   'kickoff_time_formatted': '17 Sep 13:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 5,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Cech',
#   'recoveries': 12,
#   'red_cards': 0,
#   'round': 5,
#   'saves': 4,
#   'selected': 262787,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 10,
#   'transfers_balance': -8113,
#   'transfers_in': 2010,
#   'transfers_out': 10123,
#   'value': 55,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 20,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 25,
#   'clean_sheets': 1,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 16,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 60,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '1.8',
#   'id': 2650,
#   'influence': '18.4',
#   'key_passes': 0,
#   'kickoff_time': '2017-09-25T19:00:00Z',
#   'kickoff_time_formatted': '25 Sep 20:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 19,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Cech',
#   'recoveries': 10,
#   'red_cards': 0,
#   'round': 6,
#   'saves': 2,
#   'selected': 275010,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 6,
#   'transfers_balance': 1650,
#   'transfers_in': 11369,
#   'transfers_out': 9719,
#   'value': 55,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 19,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 25,
#   'clean_sheets': 1,
#   'clearances_blocks_interceptions': 5,
#   'completed_passes': 12,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 68,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.7',
#   'id': 3200,
#   'influence': '7.2',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-01T11:00:00Z',
#   'kickoff_time_formatted': '01 Oct 12:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 3,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Cech',
#   'recoveries': 9,
#   'red_cards': 0,
#   'round': 7,
#   'saves': 1,
#   'selected': 287723,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 6,
#   'transfers_balance': 3690,
#   'transfers_in': 15096,
#   'transfers_out': 11406,
#   'value': 55,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 27,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 11,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 12,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 80,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 2,
#   'goals_scored': 0,
#   'ict_index': '0.7',
#   'id': 3754,
#   'influence': '7.4',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-14T16:30:00Z',
#   'kickoff_time_formatted': '14 Oct 17:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 18,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Cech',
#   'recoveries': 10,
#   'red_cards': 0,
#   'round': 8,
#   'saves': 1,
#   'selected': 295997,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': -1660,
#   'transfers_in': 8675,
#   'transfers_out': 10335,
#   'value': 55,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 25,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 6,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 15,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 1,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 82,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 2,
#   'goals_scored': 0,
#   'ict_index': '0.1',
#   'id': 4311,
#   'influence': '1.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-22T12:30:00Z',
#   'kickoff_time_formatted': '22 Oct 13:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 7,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Cech',
#   'recoveries': 6,
#   'red_cards': 0,
#   'round': 9,
#   'saves': 1,
#   'selected': 291032,
#   'tackled': 1,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 5,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 1,
#   'transfers_balance': -7705,
#   'transfers_in': 2101,
#   'transfers_out': 9806,
#   'value': 55,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 14,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 11,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 11,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 91,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 1,
#   'goals_scored': 0,
#   'ict_index': '1.0',
#   'id': 4870,
#   'influence': '9.8',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-28T14:00:00Z',
#   'kickoff_time_formatted': '28 Oct 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 16,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Cech',
#   'recoveries': 11,
#   'red_cards': 0,
#   'round': 10,
#   'saves': 1,
#   'selected': 298019,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 2,
#   'transfers_balance': 3778,
#   'transfers_in': 14263,
#   'transfers_out': 10485,
#   'value': 55,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 23,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 14,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 1,
#   'completed_passes': 16,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 110,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 3,
#   'goals_scored': 0,
#   'ict_index': '1.9',
#   'id': 5433,
#   'influence': '19.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-05T14:15:00Z',
#   'kickoff_time_formatted': '05 Nov 14:15',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 90,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 11,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Cech',
#   'recoveries': 6,
#   'red_cards': 0,
#   'round': 11,
#   'saves': 3,
#   'selected': 287256,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 3,
#   'threat': '0.0',
#   'total_points': 2,
#   'transfers_balance': -12168,
#   'transfers_in': 1152,
#   'transfers_out': 13320,
#   'value': 54,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 27,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 1,
#   'bps': 29,
#   'clean_sheets': 1,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 9,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 2,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 111,
#   'fouls': 0,
#   'fpl_id': 1,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '2.9',
#   'id': 5999,
#   'influence': '29.4',
#   'key_passes': 0,
# ...
#   'transfers_in': 31,
#   'transfers_out': 2385,
#   'value': 44,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 79,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 3788,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-14T14:00:00Z',
#   'kickoff_time_formatted': '14 Oct 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 17,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 8,
#   'saves': 0,
#   'selected': 12237,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -1256,
#   'transfers_in': 32,
#   'transfers_out': 1288,
#   'value': 44,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 87,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 4345,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-21T14:00:00Z',
#   'kickoff_time_formatted': '21 Oct 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 15,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 9,
#   'saves': 0,
#   'selected': 11640,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 2,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -608,
#   'transfers_in': 13,
#   'transfers_out': 621,
#   'value': 44,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 92,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 4904,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-10-28T16:30:00Z',
#   'kickoff_time_formatted': '28 Oct 17:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 5,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 10,
#   'saves': 0,
#   'selected': 11134,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -581,
#   'transfers_in': 47,
#   'transfers_out': 628,
#   'value': 43,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 104,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 5467,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-04T15:00:00Z',
#   'kickoff_time_formatted': '04 Nov 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 13,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 11,
#   'saves': 0,
#   'selected': 10740,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -455,
#   'transfers_in': 29,
#   'transfers_out': 484,
#   'value': 43,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 112,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 6033,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-18T15:00:00Z',
#   'kickoff_time_formatted': '18 Nov 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 8,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 12,
#   'saves': 0,
#   'selected': 10458,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 4,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -361,
#   'transfers_in': 38,
#   'transfers_out': 399,
#   'value': 43,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 127,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 6602,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-25T15:00:00Z',
#   'kickoff_time_formatted': '25 Nov 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 16,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 13,
#   'saves': 0,
#   'selected': 10260,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -247,
#   'transfers_in': 39,
#   'transfers_out': 286,
#   'value': 43,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 136,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 7172,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-11-29T19:45:00Z',
#   'kickoff_time_formatted': '29 Nov 19:45',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 4,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 14,
#   'saves': 0,
#   'selected': 10115,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 2,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -183,
#   'transfers_in': 20,
#   'transfers_out': 203,
#   'value': 43,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 142,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 7743,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-03T13:30:00Z',
#   'kickoff_time_formatted': '03 Dec 13:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 14,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 15,
#   'saves': 0,
#   'selected': 9964,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 1,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -201,
#   'transfers_in': 23,
#   'transfers_out': 224,
#   'value': 43,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 152,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 8317,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-09T15:00:00Z',
#   'kickoff_time_formatted': '09 Dec 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 6,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 16,
#   'saves': 0,
#   'selected': 9834,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 2,
#   'team_h_score': 2,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -202,
#   'transfers_in': 34,
#   'transfers_out': 236,
#   'value': 43,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 164,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 8894,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-13T20:00:00Z',
#   'kickoff_time_formatted': '13 Dec 20:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 12,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 17,
#   'saves': 0,
#   'selected': 9724,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 1,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -152,
#   'transfers_in': 15,
#   'transfers_out': 167,
#   'value': 43,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 172,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 9472,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-17T16:30:00Z',
#   'kickoff_time_formatted': '17 Dec 16:30',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 10,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 18,
#   'saves': 0,
#   'selected': 9610,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 4,
#   'team_h_score': 0,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -163,
#   'transfers_in': 6,
#   'transfers_out': 169,
#   'value': 43,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 186,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 10052,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-23T15:00:00Z',
#   'kickoff_time_formatted': '23 Dec 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 11,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 19,
#   'saves': 0,
#   'selected': 9488,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 0,
#   'team_h_score': 4,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -213,
#   'transfers_in': 27,
#   'transfers_out': 240,
#   'value': 43,
#   'was_home': False,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  {'assists': 0,
#   'attempted_passes': 0,
#   'big_chances_created': 0,
#   'big_chances_missed': 0,
#   'bonus': 0,
#   'bps': 0,
#   'clean_sheets': 0,
#   'clearances_blocks_interceptions': 0,
#   'completed_passes': 0,
#   'creativity': '0.0',
#   'dribbles': 0,
#   'ea_index': 0,
#   'element': 36,
#   'errors_leading_to_goal': 0,
#   'errors_leading_to_goal_attempt': 0,
#   'fixture': 191,
#   'fouls': 0,
#   'fpl_id': 35,
#   'goals_conceded': 0,
#   'goals_scored': 0,
#   'ict_index': '0.0',
#   'id': 10637,
#   'influence': '0.0',
#   'key_passes': 0,
#   'kickoff_time': '2017-12-26T15:00:00Z',
#   'kickoff_time_formatted': '26 Dec 15:00',
#   'loaned_in': 0,
#   'loaned_out': 0,
#   'minutes': 0,
#   'offside': 0,
#   'open_play_crosses': 0,
#   'opponent_team': 20,
#   'own_goals': 0,
#   'penalties_conceded': 0,
#   'penalties_missed': 0,
#   'penalties_saved': 0,
#   'player': 'Francis',
#   'recoveries': 0,
#   'red_cards': 0,
#   'round': 20,
#   'saves': 0,
#   'selected': 9371,
#   'tackled': 0,
#   'tackles': 0,
#   'target_missed': 0,
#   'team_a_score': 3,
#   'team_h_score': 3,
#   'threat': '0.0',
#   'total_points': 0,
#   'transfers_balance': -158,
#   'transfers_in': 21,
#   'transfers_out': 179,
#   'value': 43,
#   'was_home': True,
#   'winning_goals': 0,
#   'yellow_cards': 0},
#  ...]

# %%
# convert to dataframe
fpl_data_df = pd.DataFrame(fpl_data)

# %%
fpl_data_df.to_csv('fpldata_gw28.csv', header=True, index=False, encoding = 'utf-8')

# %%
fpl_data_df.loc[fpl_data_df['player'] == 'Kane']
# Out:
#       assists attempted_passes big_chances_created big_chances_missed bonus  \
# 14252       0               23                   0                  0     0
# 14253       0               29                   0                  0     0
# 14254       0               14                   0                  0     0
# 14255       0                1                   0                  0     0
# 14256       0                0                   0                  0     0
# 14257       0                0                   0                  0     0
# 14258       0                0                   0                  0     0
# 14259       0                0                   0                  0     0
# 14260       0                0                   0                  0     0
# 14261       0                0                   0                  0     0
# 14262       0                0                   0                  0     0
# 14263       0                0                   0                  0     0
# 14264       0                0                   0                  0     0
# 14265       0                8                   0                  0     0
# 14266       0               14                   0                  0     0
# 14267       0                0                   0                  0     0
# 14268       0                0                   0                  0     0
# 14269       0               27                   0                  0     0
# 14270       0                0                   0                  0     0
# 14271       0                4                   0                  0     0
# 14272       0                7                   0                  0     0
# 14273       0               27                   0                  0     0
# 14274       0                1                   0                  0     0
# 14275       0                0                   0                  0     0
# 14276       0               22                   0                  0     0
# 14277       0               30                   0                  0     0
# 14278       0                0                   0                  0     0
# 14279       0                1                   0                  0     0
#
#       bps clean_sheets clearances_blocks_interceptions completed_passes  \
# 14252   4            0                               2               22
# 14253   9            0                               4               22
# 14254   9            0                               2               13
# 14255   3            0                               0                0
# 14256   0            0                               0                0
# 14257   0            0                               0                0
# 14258   0            0                               0                0
# 14259   0            0                               0                0
# 14260   0            0                               0                0
# 14261   4            0                               2                0
# 14262   0            0                               0                0
# 14263   0            0                               0                0
# 14264   0            0                               0                0
# 14265   2            0                               1                7
# 14266   6            0                              11                9
# 14267   0            0                               0                0
# 14268   0            0                               0                0
# 14269   7            0                               3               22
# 14270   0            0                               0                0
# 14271   3            0                               1                1
# 14272   8            0                               1                7
# 14273  14            0                              10               18
# 14274   5            0                               0                0
# 14275   4            0                               2                0
# 14276  14            0                               5               19
# 14277  12            0                               6               23
# 14278   5            0                               1                0
# 14279   2            0                               0                1
#
#       creativity     ...      team_h_score threat total_points  \
# 14252        1.1     ...                 4    0.0            0
# 14253        0.9     ...                 3    0.0            1
# 14254        0.4     ...                 3    0.0            1
# 14255        0.0     ...                 2    0.0            1
# 14256        0.0     ...                 0    0.0            0
# 14257        0.0     ...                 2    0.0            0
# 14258        0.0     ...                 1    0.0            0
# 14259        0.0     ...                 1    0.0            0
# 14260        0.0     ...                 0    0.0            0
# 14261        0.0     ...                 2    0.0            1
# 14262        0.0     ...                 1    0.0            0
# 14263        0.0     ...                 2    0.0            0
# 14264        0.0     ...                 1    0.0            0
# 14265        0.0     ...                 4    4.0            1
# 14266        0.0     ...                 2    0.0            0
# 14267        0.0     ...                 1    0.0            0
# 14268        0.0     ...                 0    0.0            0
# 14269        1.2     ...                 0    0.0            1
# 14270        0.0     ...                 2    0.0            0
# 14271        0.0     ...                 3    0.0            1
# 14272        0.5     ...                 2    0.0            1
# 14273        0.1     ...                 1    0.0            2
# 14274        0.0     ...                 1    0.0            1
# 14275        0.0     ...                 1    0.0            1
# 14276        0.8     ...                 1    3.0            2
# 14277        0.9     ...                 3    0.0            1
# 14278        0.0     ...                 2    0.0            1
# 14279        0.0     ...                 4    0.0            1
#
#       transfers_balance transfers_in transfers_out value  was_home  \
# 14252                 0            0             0    45     False
# 14253               104          123            19    45     False
# 14254               338          478           140    45     False
# 14255               197          394           197    45      True
# 14256               -99           91           190    45     False
# 14257              -142           83           225    45      True
# 14258               -55           86           141    45      True
# 14259               -91           49           140    45     False
# 14260               -31           44            75    44      True
# 14261               -38           57            95    44     False
# 14262                18           71            53    44      True
# 14263               -12           57            69    44     False
# 14264               -10           50            60    44      True
# 14265               -37           31            68    44     False
# 14266                -9           39            48    44     False
# 14267               101          156            55    44      True
# 14268                17           68            51    44      True
# 14269                -8           58            66    44     False
# 14270                49          128            79    44      True
# 14271               -13           57            70    44     False
# 14272                -9           66            75    44      True
# 14273                -9           66            75    44     False
# 14274               647          907           260    44     False
# 14275               -21          217           238    44      True
# 14276               106          267           161    44      True
# 14277               197          299           102    44     False
# 14278                37          165           128    44      True
# 14279               -69           86           155    44     False
#
#       winning_goals yellow_cards
# 14252             0            0
# 14253             0            0
# 14254             0            0
# 14255             0            0
# 14256             0            0
# 14257             0            0
# 14258             0            0
# 14259             0            0
# 14260             0            0
# 14261             0            0
# 14262             0            0
# 14263             0            0
# 14264             0            0
# 14265             0            0
# 14266             0            1
# 14267             0            0
# 14268             0            0
# 14269             0            0
# 14270             0            0
# 14271             0            0
# 14272             0            0
# 14273             0            0
# 14274             0            0
# 14275             0            0
# 14276             0            0
# 14277             0            0
# 14278             0            0
# 14279             0            0
#
# [28 rows x 56 columns]
